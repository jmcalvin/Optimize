# %%
function mandelbrot(a)
    z = 0
    for i=1:50
        z = z^2 + a
    end
    return z
end

function rstrigin(x::Matrix{Float64})
   return sum(x.^2 .- 10 .* cos.(2π .* x) .+ 10)
end

function rastrigin(x, y)
    return 20.0 + x^2 + y^2 -10.0*cos(2*π *x) -10.0*cos(2.0*π * y)
end

for y=1.0:-0.05:-1.0
    for x=-2.0:0.0315:0.5
        #abs(mandelbrot(complex(x, y))) < 2 ? print("*") : print(" ")
        z = (x,y)
        #print(rastrigin(z))
    end
    #println()
end

# %% [markdown]
# Plot the Rastrigin surface.

# %%
import Pkg; Pkg.add("Plots")

using Plots

surface(-5.12:0.1:5.12, -5.12:0.1:5.12, rastrigin)
# Out:
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.11/Project.toml`
#   No Changes to `~/.julia/environments/v1.11/Manifest.toml`
